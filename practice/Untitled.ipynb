# %%
import multiprocessing
import os, sys
import pickle
import neat
import numpy as np
#import cart_pole
import gym
import gym_snake

# %%
runs_per_net = 2

# %%
# Use the NN network phenotype and the discrete actuator force function.
def eval_genome(genome, config):
    net = neat.nn.FeedForwardNetwork.create(genome, config)

    fitnesses = []

    for runs in range(runs_per_net):
        env = gym.make("CartPole-v1")

        observation = env.reset()
        fitness = 0.0
        turns = 0
        done = False
        while not done:
            vals = net.activate(observation)
            action = np.argmax(vals)
            observation, reward, done, info = env.step(action)
            fitness += reward
        fitnesses.append(fitness)

    return np.mean(fitnesses)

# %%
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = eval_genome(genome, config)

# %%
def run():
    # Load the config file, which is assumed to live in
    # the same directory as this script.
    local_dir = os.path.dirname(os.path.abspath("__file__"))
    config_path = os.path.join(local_dir, 'config')
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_path)

    pop = neat.Population(config)
    stats = neat.StatisticsReporter()
    pop.add_reporter(stats)
    pop.add_reporter(neat.StdOutReporter(True))

    pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
    winner = pop.run(pe.evaluate)

    # Save the winner.
    with open('winner', 'wb') as f:
        pickle.dump(winner, f)

    print(winner)

# %%
run()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 13.88600 stdev: 11.66422
# Best fitness: 90.00000 - size: (2, 4) - species 1 - id 46
# Average adjusted fitness: 0.072
# Mean genetic distance 1.921, standard deviation 0.448
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   195     90.0    0.072     0
#      2    0    55       --       --     0
# Total extinctions: 0
# Generation time: 0.134 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 31.59600 stdev: 51.87459
# Best fitness: 500.00000 - size: (2, 3) - species 1 - id 300
# Average adjusted fitness: 0.052
# Mean genetic distance 2.023, standard deviation 0.495
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   164    500.0    0.043     0
#      2    1    86    247.5    0.061     0
# Total extinctions: 0
# Generation time: 0.174 sec (0.154 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 56.24800 stdev: 85.11522
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 530
# Average adjusted fitness: 0.106
# Mean genetic distance 1.860, standard deviation 0.503
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   114    500.0    0.081     1
#      2    2   136    500.0    0.131     0
# Total extinctions: 0
# Generation time: 0.240 sec (0.183 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 77.38000 stdev: 115.44100
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 530
# Average adjusted fitness: 0.138
# Mean genetic distance 1.771, standard deviation 0.413
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   107    500.0    0.109     2
#      2    3   143    500.0    0.168     1
# Total extinctions: 0
# Generation time: 0.285 sec (0.208 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 100.61600 stdev: 129.96016
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 530
# Average adjusted fitness: 0.185
# Mean genetic distance 1.711, standard deviation 0.365
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    61    500.0    0.165     3
#      2    4   189    500.0    0.206     2
# Total extinctions: 0
# Generation time: 0.387 sec (0.244 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 112.85000 stdev: 149.60693
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 1031
# Average adjusted fitness: 0.210
# Mean genetic distance 1.572, standard deviation 0.420
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    40    500.0    0.204     4
#      2    5   210    500.0    0.216     3
# Total extinctions: 0
# Generation time: 0.398 sec (0.270 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 117.81000 stdev: 151.97667
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 1031
# Average adjusted fitness: 0.228
# Mean genetic distance 1.474, standard deviation 0.416
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    52    500.0    0.237     5
#      2    6   198    500.0    0.220     4
# Total extinctions: 0
# Generation time: 0.396 sec (0.288 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 114.06800 stdev: 142.28411
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 1538
# Average adjusted fitness: 0.191
# Mean genetic distance 1.447, standard deviation 0.420
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   114    432.0    0.150     6
#      2    7   136    500.0    0.232     5
# Total extinctions: 0
# Generation time: 0.425 sec (0.305 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 116.57000 stdev: 152.35988
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 1977
# Average adjusted fitness: 0.216
# Mean genetic distance 1.458, standard deviation 0.460
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   138    500.0    0.165     7
#      2    8   112    500.0    0.268     6
# Total extinctions: 0
# Generation time: 0.411 sec (0.317 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 172.37000 stdev: 175.79387
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 1977
# Average adjusted fitness: 0.335
# Mean genetic distance 1.411, standard deviation 0.433
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   132    500.0    0.325     8
#      2    9   118    500.0    0.346     7
# Total extinctions: 0
# Generation time: 0.547 sec (0.340 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 166.19600 stdev: 174.10264
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 2288
# Average adjusted fitness: 0.323
# Mean genetic distance 1.458, standard deviation 0.417
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    84    500.0    0.289     9
#      2   10   166    500.0    0.358     8
# Total extinctions: 0
# Generation time: 0.520 sec (0.378 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 169.23400 stdev: 177.93277
# Best fitness: 500.00000 - size: (2, 3) - species 1 - id 2588
# Average adjusted fitness: 0.319
# Mean genetic distance 1.537, standard deviation 0.437
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    82    500.0    0.292    10
#      2   11   168    500.0    0.346     9
# Total extinctions: 0
# Generation time: 0.607 sec (0.422 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 168.72400 stdev: 184.46905
# Best fitness: 500.00000 - size: (2, 3) - species 1 - id 2588
# Average adjusted fitness: 0.344
# Mean genetic distance 1.515, standard deviation 0.475
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   140    500.0    0.393    11
#      2   12   110    500.0    0.294    10
# Total extinctions: 0
# Generation time: 0.545 sec (0.452 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 192.39000 stdev: 194.71349
# Best fitness: 500.00000 - size: (2, 3) - species 1 - id 2588
# Average adjusted fitness: 0.375
# Mean genetic distance 1.603, standard deviation 0.450
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   134    500.0    0.376    12
#      2   13   116    500.0    0.373    11
# Total extinctions: 0
# Generation time: 0.627 sec (0.486 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 170.44200 stdev: 183.09696
# Best fitness: 500.00000 - size: (2, 3) - species 1 - id 2588
# Average adjusted fitness: 0.332
# Mean genetic distance 1.864, standard deviation 0.655
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   105    500.0    0.311    13
#      2   14   133    500.0    0.353    12
#      3    0    12       --       --     0
# Total extinctions: 0
# Generation time: 0.559 sec (0.504 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 206.90400 stdev: 194.91864
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 3161
# Average adjusted fitness: 0.383
# Mean genetic distance 1.993, standard deviation 0.652
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    77    500.0    0.383    14
#      2   15   109    500.0    0.426    13
#      3    1    64    500.0    0.340     0
# Total extinctions: 0
# Generation time: 0.643 sec (0.528 average)
#
#  ****** Running generation 16 ******
# Population's average fitness: 211.59800 stdev: 200.42569
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 3762
# Average adjusted fitness: 0.409
# Mean genetic distance 1.873, standard deviation 0.495
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    69    500.0    0.335    15
#      2   16   112    500.0    0.459    14
#      3    2    69    500.0    0.431     1
# Total extinctions: 0
# Generation time: 0.655 sec (0.554 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 188.73000 stdev: 189.41669
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 3762
# Average adjusted fitness: 0.379
# Mean genetic distance 2.088, standard deviation 0.726
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    58    500.0    0.367    16
#      2   17    98    500.0    0.311    15
#      3    3    83    500.0    0.459     2
#      4    0    11       --       --     0
# Total extinctions: 0
# Generation time: 0.590 sec (0.570 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 188.82200 stdev: 190.13634
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 3762
# Average adjusted fitness: 0.393
# Mean genetic distance 2.153, standard deviation 0.686
# Population of 249 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    59    500.0    0.364    17
#      2   18    80    500.0    0.303    16
#      3    4    66    500.0    0.432     3
#      4    1    44    500.0    0.471     0
# Total extinctions: 0
# Generation time: 0.602 sec (0.589 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 216.10040 stdev: 200.92490
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 3762
# Average adjusted fitness: 0.432
# Mean genetic distance 2.133, standard deviation 0.653
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    59    500.0    0.336    18
#      2   19    76    500.0    0.396    17
#      3    5    67    500.0    0.446     4
#      4    2    48    500.0    0.552     1
# Total extinctions: 0
# Generation time: 0.660 sec (0.601 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 235.30800 stdev: 207.06624
# Best fitness: 500.00000 - size: (2, 5) - species 1 - id 4684
# Average adjusted fitness: 0.453
# Mean genetic distance 2.099, standard deviation 0.604
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    62    500.0    0.318    19
#      2   20    76    500.0    0.579    18
#      3    6    63    500.0    0.454     5
#      4    3    49    500.0    0.463     2
# Total extinctions: 0
# Generation time: 0.703 sec (0.619 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 211.06400 stdev: 200.71798
# Best fitness: 500.00000 - size: (2, 4) - species 1 - id 5121
#
# Species 1 with 62 members is stagnated: removing it
# Average adjusted fitness: 0.429
# Mean genetic distance 2.075, standard deviation 0.673
# Population of 249 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   21    88    500.0    0.363    19
#      3    7    80    500.0    0.362     6
#      4    4    81    500.0    0.561     3
# Total extinctions: 0
# Generation time: 0.653 sec (0.623 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 224.13855 stdev: 200.91395
# Best fitness: 500.00000 - size: (2, 4) - species 2 - id 2190
#
# Species 2 with 88 members is stagnated: removing it
# Average adjusted fitness: 0.472
# Mean genetic distance 1.750, standard deviation 0.549
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3    8   133    500.0    0.383     7
#      4    5   117    500.0    0.561     4
# Total extinctions: 0
# Generation time: 0.690 sec (0.638 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 241.15200 stdev: 197.17281
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.479
# Mean genetic distance 1.929, standard deviation 0.679
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3    9   132    500.0    0.396     8
#      4    6   109    500.0    0.561     5
#      5    0     9       --       --     0
# Total extinctions: 0
# Generation time: 0.725 sec (0.648 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 240.61400 stdev: 201.65040
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.391
# Mean genetic distance 2.446, standard deviation 0.848
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   10   123    500.0    0.420     9
#      4    7   102    500.0    0.559     6
#      5    1    25    500.0    0.193     0
# Total extinctions: 0
# Generation time: 0.745 sec (0.666 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 230.37400 stdev: 213.38920
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.435
# Mean genetic distance 2.383, standard deviation 0.742
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   11    88    500.0    0.344    10
#      4    8    85    500.0    0.604     7
#      5    2    77    500.0    0.358     1
# Total extinctions: 0
# Generation time: 0.735 sec (0.676 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 239.03000 stdev: 201.96643
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.470
# Mean genetic distance 2.173, standard deviation 0.661
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   12    66    500.0    0.401    11
#      4    9    60    500.0    0.559     8
#      5    3   115    500.0    0.449     2
#      6    0     9       --       --     0
# Total extinctions: 0
# Generation time: 0.745 sec (0.685 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 251.19400 stdev: 202.93413
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.448
# Mean genetic distance 2.166, standard deviation 0.670
# Population of 249 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   13    45    500.0    0.467    12
#      4   10    57    500.0    0.608     9
#      5    4    71    500.0    0.469     3
#      6    1    76    265.5    0.247     0
# Total extinctions: 0
# Generation time: 0.749 sec (0.701 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 257.61245 stdev: 204.79001
# Best fitness: 500.00000 - size: (2, 4) - species 3 - id 4808
# Average adjusted fitness: 0.506
# Mean genetic distance 2.059, standard deviation 0.644
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   14    44    500.0    0.409    13
#      4   11    65    500.0    0.674    10
#      5    5    70    500.0    0.445     4
#      6    2    66    500.0    0.497     0
#      7    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.778 sec (0.718 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 254.80600 stdev: 207.22187
# Best fitness: 500.00000 - size: (2, 3) - species 6 - id 6952
# Average adjusted fitness: 0.412
# Mean genetic distance 2.509, standard deviation 0.874
# Population of 250 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   15    56    500.0    0.421    14
#      4   12    48    500.0    0.531    11
#      5    6    82    500.0    0.436     5
#      6    3    52    500.0    0.631     1
#      7    1     4     91.5    0.043     0
#      8    0     8       --       --     0
# Total extinctions: 0
# Generation time: 0.768 sec (0.729 average)
#
#  ****** Running generation 30 ******
# Population's average fitness: 250.98200 stdev: 207.39668
# Best fitness: 500.00000 - size: (2, 3) - species 5 - id 7351
# Average adjusted fitness: 0.503
# Mean genetic distance 2.545, standard deviation 0.863
# Population of 251 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   16    41    500.0    0.402    15
#      4   13    35    500.0    0.643    12
#      5    7    83    500.0    0.423     6
#      6    4    29    500.0    0.543     2
#      7    2     5    500.0    0.259     0
#      8    1    58    500.0    0.745     0
# Total extinctions: 0
# Generation time: 0.792 sec (0.738 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 258.39044 stdev: 210.57697
# Best fitness: 500.00000 - size: (2, 3) - species 8 - id 7405
# Average adjusted fitness: 0.471
# Mean genetic distance 2.459, standard deviation 0.852
# Population of 251 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   17    24    500.0    0.397    16
#      4   14    43    500.0    0.669    13
#      5    8    56    500.0    0.422     7
#      6    5    62    500.0    0.474     3
#      7    3     5    500.0    0.205     1
#      8    2    61    500.0    0.658     1
# Total extinctions: 0
# Generation time: 0.794 sec (0.752 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 245.95219 stdev: 207.18671
# Best fitness: 500.00000 - size: (4, 5) - species 8 - id 7596
# Average adjusted fitness: 0.392
# Mean genetic distance 2.360, standard deviation 0.798
# Population of 250 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   18    39    500.0    0.307    17
#      4   15    40    500.0    0.507    14
#      5    9    87    500.0    0.453     8
#      6    6    32    500.0    0.576     4
#      7    4    13     10.0    0.002     2
#      8    3    39    500.0    0.509     2
# Total extinctions: 0
# Generation time: 0.755 sec (0.759 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 223.79200 stdev: 203.03922
# Best fitness: 500.00000 - size: (2, 3) - species 6 - id 7694
# Average adjusted fitness: 0.398
# Mean genetic distance 2.454, standard deviation 0.847
# Population of 250 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   19    38    500.0    0.296    18
#      4   16    39    500.0    0.596    15
#      5   10    84    500.0    0.421     9
#      6    7    23    500.0    0.451     5
#      7    5    18    169.5    0.046     3
#      8    4    48    500.0    0.580     3
# Total extinctions: 0
# Generation time: 0.703 sec (0.756 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 227.86600 stdev: 204.26009
# Best fitness: 500.00000 - size: (3, 2) - species 7 - id 8306
# Average adjusted fitness: 0.430
# Mean genetic distance 2.462, standard deviation 0.778
# Population of 251 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      3   20    40    500.0    0.426    19
#      4   17    37    500.0    0.635    16
#      5   11    71    500.0    0.405    10
#      6    8    35    500.0    0.346     6
#      7    6    18    500.0    0.266     4
#      8    5    50    500.0    0.501     4
# Total extinctions: 0
# Generation time: 0.692 sec (0.751 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 230.21116 stdev: 200.95541
# Best fitness: 500.00000 - size: (3, 2) - species 7 - id 8306
#
# Species 3 with 40 members is stagnated: removing it
# Average adjusted fitness: 0.421
# Mean genetic distance 2.485, standard deviation 0.789
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   18    50    500.0    0.614    17
#      5   12    83    500.0    0.354    11
#      6    9    47    500.0    0.478     7
#      7    7    10    500.0    0.153     5
#      8    6    59    500.0    0.505     5
# Total extinctions: 0
# Generation time: 0.699 sec (0.747 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 267.04418 stdev: 205.86217
# Best fitness: 500.00000 - size: (3, 2) - species 7 - id 8306
# Average adjusted fitness: 0.491
# Mean genetic distance 2.559, standard deviation 0.863
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   19    54    500.0    0.768    18
#      5   13    84    500.0    0.470    12
#      6   10    47    500.0    0.480     8
#      7    8    14    500.0    0.254     6
#      8    7    50    500.0    0.482     6
# Total extinctions: 0
# Generation time: 0.804 sec (0.753 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 247.03414 stdev: 208.55576
# Best fitness: 500.00000 - size: (3, 4) - species 7 - id 8999
# Average adjusted fitness: 0.454
# Mean genetic distance 2.581, standard deviation 0.918
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   20    58    500.0    0.678    19
#      5   14    68    500.0    0.374    13
#      6   11    48    500.0    0.427     9
#      7    9    23    500.0    0.185     7
#      8    8    53    500.0    0.605     7
# Total extinctions: 0
# Generation time: 0.725 sec (0.751 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 261.86800 stdev: 203.15624
# Best fitness: 500.00000 - size: (3, 4) - species 7 - id 8999
#
# Species 4 with 58 members is stagnated: removing it
# Average adjusted fitness: 0.421
# Mean genetic distance 2.524, standard deviation 0.915
# Population of 249 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   15    82    500.0    0.454    14
#      6   12    58    500.0    0.394    10
#      7   10    23    500.0    0.165     8
#      8    9    86    500.0    0.672     8
# Total extinctions: 0
# Generation time: 0.783 sec (0.751 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 249.57229 stdev: 213.68346
# Best fitness: 500.00000 - size: (3, 5) - species 7 - id 9275
# Average adjusted fitness: 0.432
# Mean genetic distance 2.555, standard deviation 0.888
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   16    97    500.0    0.452    15
#      6   13    53    500.0    0.433    11
#      7   11    28    500.0    0.198     9
#      8   10    72    500.0    0.645     9
# Total extinctions: 0
# Generation time: 0.741 sec (0.749 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 255.45400 stdev: 212.88099
# Best fitness: 500.00000 - size: (3, 5) - species 7 - id 9275
# Average adjusted fitness: 0.474
# Mean genetic distance 2.614, standard deviation 0.925
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   17    97    500.0    0.457    16
#      6   14    57    500.0    0.576    12
#      7   12    25    500.0    0.260    10
#      8   11    71    500.0    0.603    10
# Total extinctions: 0
# Generation time: 0.748 sec (0.744 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 221.97400 stdev: 205.48647
# Best fitness: 500.00000 - size: (3, 5) - species 7 - id 9759
# Average adjusted fitness: 0.397
# Mean genetic distance 2.721, standard deviation 0.926
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   18    98    500.0    0.393    17
#      6   15    52    500.0    0.448    13
#      7   13    32    500.0    0.174    11
#      8   12    68    500.0    0.572    11
# Total extinctions: 0
# Generation time: 0.674 sec (0.732 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 231.49000 stdev: 202.55408
# Best fitness: 500.00000 - size: (3, 5) - species 7 - id 9759
# Average adjusted fitness: 0.415
# Mean genetic distance 2.659, standard deviation 0.894
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   19   101    500.0    0.467    18
#      6   16    50    500.0    0.340    14
#      7   14    43    500.0    0.222    12
#      8   13    56    500.0    0.631    12
# Total extinctions: 0
# Generation time: 0.687 sec (0.726 average)
#
#  ****** Running generation 43 ******
# Population's average fitness: 214.51000 stdev: 200.28274
# Best fitness: 500.00000 - size: (3, 5) - species 7 - id 9759
# Average adjusted fitness: 0.418
# Mean genetic distance 2.621, standard deviation 0.955
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   20   104    500.0    0.377    19
#      6   17    60    500.0    0.482    15
#      7   15    27    500.0    0.218    13
#      8   14    50    500.0    0.592    13
#      9    0     9       --       --     0
# Total extinctions: 0
# Generation time: 0.645 sec (0.720 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 239.45400 stdev: 204.45291
# Best fitness: 500.00000 - size: (3, 5) - species 8 - id 9759
#
# Species 5 with 104 members is stagnated: removing it
# Average adjusted fitness: 0.441
# Mean genetic distance 3.038, standard deviation 1.179
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      6   18    83    500.0    0.441    16
#      7   16    63    500.0    0.707    14
#      8   15    80    500.0    0.526    14
#      9    1    24    299.0    0.090     0
# Total extinctions: 0
# Generation time: 0.711 sec (0.722 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 262.28200 stdev: 213.66468
# Best fitness: 500.00000 - size: (3, 4) - species 8 - id 10956
# Average adjusted fitness: 0.441
# Mean genetic distance 2.960, standard deviation 1.107
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      6   19    82    500.0    0.577    17
#      7   17    51    500.0    0.530    15
#      8   16    67    500.0    0.571    15
#      9    2    36    500.0    0.088     0
#     10    0    14       --       --     0
# Total extinctions: 0
# Generation time: 0.773 sec (0.729 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 234.30800 stdev: 205.13990
# Best fitness: 500.00000 - size: (3, 5) - species 9 - id 9759
# Average adjusted fitness: 0.473
# Mean genetic distance 2.945, standard deviation 1.009
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      6   20    67    500.0    0.428    18
#      7   18    26    500.0    0.547    16
#      8   17    64    500.0    0.566    16
#      9    3    36    500.0    0.115     1
#     10    1    57    500.0    0.712     0
# Total extinctions: 0
# Generation time: 0.736 sec (0.722 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 226.46200 stdev: 203.84891
# Best fitness: 500.00000 - size: (3, 5) - species 9 - id 9759
# Average adjusted fitness: 0.458
# Mean genetic distance 2.876, standard deviation 1.016
# Population of 250 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      6   21    61    500.0    0.416    19
#      7   19    17    500.0    0.786    17
#      8   18    40    500.0    0.496    17
#      9    4    74    500.0    0.127     2
#     10    2    56    500.0    0.463     1
#     11    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.689 sec (0.719 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 228.44600 stdev: 208.98828
# Best fitness: 500.00000 - size: (3, 5) - species 9 - id 9759
#
# Species 6 with 61 members is stagnated: removing it
# Average adjusted fitness: 0.410
# Mean genetic distance 2.802, standard deviation 1.147
# Population of 250 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   20    39    500.0    0.467    18
#      8   19    76    500.0    0.505    18
#      9    5    43    500.0    0.427     3
#     10    3    57    500.0    0.556     2
#     11    1    13     59.0    0.093     0
#     12    0     5       --       --     0
#     13    0    15       --       --     0
#     14    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.730 sec (0.713 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 255.30000 stdev: 217.95623
# Best fitness: 500.00000 - size: (2, 3) - species 9 - id 11265
# Average adjusted fitness: 0.386
# Mean genetic distance 3.021, standard deviation 1.083
# Population of 252 members in 8 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   21    36    500.0    0.693    19
#      8   20    47    500.0    0.483    19
#      9    6    38    500.0    0.559     4
#     10    4    36    500.0    0.605     3
#     11    2    12    116.5    0.099     0
#     12    1    28    232.0    0.104     0
#     13    1    33    151.0    0.029     0
#     14    1    22    334.5    0.518     0
# Total extinctions: 0
# Generation time: 0.800 sec (0.719 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 237.71032 stdev: 214.00628
# Best fitness: 500.00000 - size: (2, 3) - species 14 - id 12193
#
# Species 7 with 36 members is stagnated: removing it
#
# Species 8 with 47 members is stagnated: removing it
# Average adjusted fitness: 0.357
# Mean genetic distance 3.005, standard deviation 1.118
# Population of 250 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9    7    53    500.0    0.626     5
#     10    5    67    500.0    0.746     4
#     11    3    42    237.0    0.188     0
#     12    2    25    500.0    0.195     0
#     13    2    31    500.0    0.105     0
#     14    2    32    500.0    0.279     0
# Total extinctions: 0
# Generation time: 0.722 sec (0.717 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 212.01000 stdev: 211.69071
# Best fitness: 500.00000 - size: (2, 3) - species 11 - id 12402
# Average adjusted fitness: 0.360
# Mean genetic distance 2.998, standard deviation 1.075
# Population of 249 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9    8    54    500.0    0.560     6
#     10    6    58    500.0    0.612     5
#     11    4    29    500.0    0.300     0
#     12    3    34    500.0    0.212     1
#     13    3    20    500.0    0.171     1
#     14    3    54    500.0    0.305     1
# Total extinctions: 0
# Generation time: 0.674 sec (0.717 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 220.27309 stdev: 205.78175
# Best fitness: 500.00000 - size: (2, 3) - species 14 - id 12402
# Average adjusted fitness: 0.374
# Mean genetic distance 3.032, standard deviation 1.078
# Population of 249 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9    9    41    500.0    0.578     7
#     10    7    55    500.0    0.629     6
#     11    5    61    500.0    0.227     1
#     12    4    20    500.0    0.205     2
#     13    4    21    500.0    0.192     2
#     14    4    41    500.0    0.411     2
#     15    0    10       --       --     0
# Total extinctions: 0
# Generation time: 0.732 sec (0.721 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 236.18474 stdev: 210.40369
# Best fitness: 500.00000 - size: (2, 3) - species 11 - id 12658
# Average adjusted fitness: 0.399
# Mean genetic distance 3.145, standard deviation 1.132
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   10    38    500.0    0.611     8
#     10    8    58    500.0    0.650     7
#     11    6    47    500.0    0.431     2
#     12    5     2    500.0    0.104     3
#     13    5    50    418.5    0.122     3
#     14    5    30    500.0    0.483     3
#     15    1    26    500.0    0.393     0
# Total extinctions: 0
# Generation time: 0.711 sec (0.728 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 222.37450 stdev: 200.20246
# Best fitness: 500.00000 - size: (2, 3) - species 11 - id 12939
# Average adjusted fitness: 0.370
# Mean genetic distance 2.980, standard deviation 1.075
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   11    41    500.0    0.574     9
#     10    9    42    500.0    0.513     8
#     11    7    59    500.0    0.484     3
#     12    6     3      9.5    0.002     4
#     13    6    26    500.0    0.317     4
#     14    6    43    500.0    0.269     4
#     15    2    37    500.0    0.427     1
# Total extinctions: 0
# Generation time: 0.709 sec (0.728 average)
#
#  ****** Running generation 55 ******
# Population's average fitness: 235.66135 stdev: 212.88935
# Best fitness: 500.00000 - size: (2, 3) - species 14 - id 13322
# Average adjusted fitness: 0.375
# Mean genetic distance 2.984, standard deviation 1.056
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   12    36    500.0    0.588    10
#     10   10    47    500.0    0.602     9
#     11    8    65    500.0    0.552     4
#     12    7    12      9.5    0.003     5
#     13    7    33    500.0    0.132     5
#     14    7    37    500.0    0.500     5
#     15    3    20    500.0    0.251     2
# Total extinctions: 0
# Generation time: 0.748 sec (0.725 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 256.47400 stdev: 211.78732
# Best fitness: 500.00000 - size: (2, 3) - species 13 - id 13343
# Average adjusted fitness: 0.446
# Mean genetic distance 2.927, standard deviation 1.083
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   13    30    500.0    0.605    11
#     10   11    38    500.0    0.683    10
#     11    9    75    500.0    0.623     5
#     12    8    19    500.0    0.278     6
#     13    8    31    500.0    0.201     6
#     14    8    28    500.0    0.429     6
#     15    4    29    500.0    0.303     3
# Total extinctions: 0
# Generation time: 0.785 sec (0.730 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 257.41800 stdev: 212.14103
# Best fitness: 500.00000 - size: (2, 2) - species 12 - id 13798
# Average adjusted fitness: 0.477
# Mean genetic distance 2.930, standard deviation 1.171
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   14    30    500.0    0.654    12
#     10   12    22    500.0    0.613    11
#     11   10    78    500.0    0.610     6
#     12    9    25    500.0    0.457     7
#     13    9    35    500.0    0.303     7
#     14    9    37    500.0    0.473     7
#     15    5    23    500.0    0.230     4
# Total extinctions: 0
# Generation time: 0.800 sec (0.741 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 282.77000 stdev: 216.85391
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 13952
# Average adjusted fitness: 0.552
# Mean genetic distance 2.880, standard deviation 1.153
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   15    30    500.0    0.712    13
#     10   13    27    500.0    0.709    12
#     11   11    68    500.0    0.647     7
#     12   10    32    500.0    0.768     8
#     13   10    36    500.0    0.307     8
#     14   10    32    500.0    0.409     8
#     15    6    25    500.0    0.309     5
# Total extinctions: 0
# Generation time: 0.870 sec (0.755 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 285.25800 stdev: 208.25977
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 14211
# Average adjusted fitness: 0.542
# Mean genetic distance 2.927, standard deviation 1.166
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   16    28    500.0    0.536    14
#     10   14    26    500.0    0.689    13
#     11   12    57    500.0    0.700     8
#     12   11    34    500.0    0.606     9
#     13   11    57    500.0    0.296     9
#     14   11    26    500.0    0.609     9
#     15    7    22    500.0    0.359     6
# Total extinctions: 0
# Generation time: 0.849 sec (0.760 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 278.19200 stdev: 204.69288
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 14211
# Average adjusted fitness: 0.548
# Mean genetic distance 2.904, standard deviation 1.149
# Population of 250 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   17    29    500.0    0.718    15
#     10   15    29    500.0    0.641    14
#     11   13    50    500.0    0.625     9
#     12   12    28    500.0    0.503    10
#     13   12    57    500.0    0.463    10
#     14   12    31    500.0    0.462    10
#     15    8    26    500.0    0.423     7
# Total extinctions: 0
# Generation time: 0.847 sec (0.773 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 253.68400 stdev: 216.70441
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 14211
# Average adjusted fitness: 0.510
# Mean genetic distance 2.827, standard deviation 1.149
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   18    35    500.0    0.612    16
#     10   16    24    500.0    0.635    15
#     11   14    58    500.0    0.623    10
#     12   13    25    500.0    0.718    11
#     13   13    56    500.0    0.318    11
#     14   13    27    500.0    0.406    11
#     15    9    26    500.0    0.258     8
# Total extinctions: 0
# Generation time: 0.773 sec (0.782 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 254.20319 stdev: 208.70950
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 14211
# Average adjusted fitness: 0.496
# Mean genetic distance 2.806, standard deviation 1.156
# Population of 252 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   19    28    500.0    0.562    17
#     10   17    29    500.0    0.661    16
#     11   15    62    500.0    0.629    11
#     12   14    34    500.0    0.669    12
#     13   14    43    500.0    0.390    12
#     14   14    32    500.0    0.391    12
#     15   10    24    500.0    0.172     9
# Total extinctions: 0
# Generation time: 0.764 sec (0.786 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 277.49405 stdev: 204.53797
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 14905
# Average adjusted fitness: 0.533
# Mean genetic distance 2.860, standard deviation 1.155
# Population of 251 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   20    28    500.0    0.598    18
#     10   18    26    500.0    0.628    17
#     11   16    67    500.0    0.585    12
#     12   15    33    500.0    0.730    13
#     13   15    35    500.0    0.440    13
#     14   15    42    500.0    0.611    13
#     15   11    20    500.0    0.143    10
# Total extinctions: 0
# Generation time: 0.854 sec (0.800 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 254.33665 stdev: 213.41707
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15386
# Average adjusted fitness: 0.493
# Mean genetic distance 2.857, standard deviation 1.113
# Population of 252 members in 7 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   21    35    500.0    0.750    19
#     10   19    31    500.0    0.682    18
#     11   17    52    500.0    0.532    13
#     12   16    36    500.0    0.525    14
#     13   16    46    500.0    0.336    14
#     14   16    35    500.0    0.438    14
#     15   12    17    500.0    0.185    11
# Total extinctions: 0
# Generation time: 0.795 sec (0.809 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 237.62103 stdev: 213.26059
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
#
# Species 9 with 35 members is stagnated: removing it
# Average adjusted fitness: 0.431
# Mean genetic distance 2.785, standard deviation 1.129
# Population of 251 members in 6 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     10   20    44    500.0    0.650    19
#     11   18    60    500.0    0.554    14
#     12   17    32    500.0    0.384    15
#     13   17    50    500.0    0.340    15
#     14   17    35    500.0    0.340    15
#     15   13    30    500.0    0.320    12
# Total extinctions: 0
# Generation time: 0.765 sec (0.810 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 274.61554 stdev: 206.87768
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
#
# Species 10 with 44 members is stagnated: removing it
# Average adjusted fitness: 0.481
# Mean genetic distance 2.680, standard deviation 1.172
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   19    57    500.0    0.590    15
#     12   18    45    500.0    0.623    16
#     13   18    68    500.0    0.437    16
#     14   18    39    500.0    0.373    16
#     15   14    40    500.0    0.382    13
# Total extinctions: 0
# Generation time: 0.878 sec (0.820 average)
#
#  ****** Running generation 67 ******
# Population's average fitness: 254.92972 stdev: 213.95176
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
# Average adjusted fitness: 0.498
# Mean genetic distance 2.680, standard deviation 1.171
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   20    64    500.0    0.632    16
#     12   19    46    500.0    0.726    17
#     13   19    58    500.0    0.410    17
#     14   19    47    500.0    0.416    17
#     15   15    34    500.0    0.303    14
# Total extinctions: 0
# Generation time: 0.799 sec (0.820 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 245.72691 stdev: 213.28608
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
# Average adjusted fitness: 0.472
# Mean genetic distance 2.700, standard deviation 1.158
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   21    63    500.0    0.596    17
#     12   20    35    500.0    0.421    18
#     13   20    50    500.0    0.438    18
#     14   20    59    500.0    0.506    18
#     15   16    42    500.0    0.396    15
# Total extinctions: 0
# Generation time: 0.761 sec (0.809 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 255.73092 stdev: 207.97670
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
# Average adjusted fitness: 0.496
# Mean genetic distance 2.702, standard deviation 1.125
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   22    59    500.0    0.632    18
#     12   21    39    500.0    0.611    19
#     13   21    48    500.0    0.397    19
#     14   21    67    500.0    0.530    19
#     15   17    37    500.0    0.307    16
# Total extinctions: 0
# Generation time: 0.779 sec (0.802 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 235.77400 stdev: 213.43225
# Best fitness: 500.00000 - size: (2, 3) - species 12 - id 15651
#
# Species 12 with 39 members is stagnated: removing it
#
# Species 13 with 48 members is stagnated: removing it
#
# Species 14 with 67 members is stagnated: removing it
# Average adjusted fitness: 0.437
# Mean genetic distance 2.837, standard deviation 1.333
# Population of 250 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     11   23   151    500.0    0.572    19
#     15   18    84    500.0    0.302    17
#     16    0    15       --       --     0
# Total extinctions: 0
# Generation time: 0.725 sec (0.789 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 250.24800 stdev: 214.09331
# Best fitness: 500.00000 - size: (2, 3) - species 11 - id 14358
#
# Species 11 with 151 members is stagnated: removing it
# Average adjusted fitness: 0.170
# Mean genetic distance 2.552, standard deviation 0.968
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   19   197    500.0    0.336    18
#     16    1    53     16.5    0.004     0
# Total extinctions: 0
# Generation time: 0.763 sec (0.788 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 158.28000 stdev: 184.77364
# Best fitness: 500.00000 - size: (2, 3) - species 15 - id 13326
# Average adjusted fitness: 0.259
# Mean genetic distance 2.291, standard deviation 0.795
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     15   20   165    500.0    0.340    19
#     16    2    85    500.0    0.178     0
# Total extinctions: 0
# Generation time: 0.496 sec (0.762 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 178.54400 stdev: 196.50404
# Best fitness: 500.00000 - size: (2, 3) - species 16 - id 17436
#
# Species 15 with 165 members is stagnated: removing it
# Average adjusted fitness: 0.388
# Mean genetic distance 1.489, standard deviation 0.424
# Population of 250 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16    3   250    500.0    0.388     1
# Total extinctions: 0
# Generation time: 0.557 sec (0.732 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 235.51200 stdev: 205.81505
# Best fitness: 500.00000 - size: (2, 3) - species 16 - id 17436
# Average adjusted fitness: 0.462
# Mean genetic distance 1.463, standard deviation 0.437
# Population of 250 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16    4   250    500.0    0.462     2
# Total extinctions: 0
# Generation time: 0.699 sec (0.722 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 207.33200 stdev: 198.42596
# Best fitness: 500.00000 - size: (2, 3) - species 16 - id 17921
# Average adjusted fitness: 0.405
# Mean genetic distance 1.579, standard deviation 0.445
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16    5   249    500.0    0.405     3
#     17    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.628 sec (0.708 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 210.01800 stdev: 200.03633
# Best fitness: 500.00000 - size: (2, 3) - species 16 - id 17921
# Average adjusted fitness: 0.215
# Mean genetic distance 1.974, standard deviation 0.637
# Population of 250 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     16    6   215    500.0    0.412     4
# ...
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    434   22   137    500.0    0.659    15
#    436    9   101    500.0    0.539     8
#    437    0     5       --       --     0
#    438    0     7       --       --     0
# Total extinctions: 0
# Generation time: 1.023 sec (1.111 average)
#
#  ****** Running generation 1668 ******
#
# Population's average fitness: 351.29400 stdev: 182.87283
# Best fitness: 500.00000 - size: (18, 12) - species 434 - id 396354
# Average adjusted fitness: 0.551
# Mean genetic distance 2.777, standard deviation 0.564
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    434   23   104    500.0    0.782    16
#    436   10    70    500.0    0.615     9
#    437    1    28    500.0    0.287     0
#    438    1    40    500.0    0.521     0
#    439    0     8       --       --     0
# Total extinctions: 0
# Generation time: 1.159 sec (1.111 average)
#
#  ****** Running generation 1669 ******
#
# Population's average fitness: 298.92000 stdev: 192.82157
# Best fitness: 500.00000 - size: (18, 12) - species 434 - id 396354
# Average adjusted fitness: 0.490
# Mean genetic distance 2.744, standard deviation 0.584
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    434   24    85    500.0    0.671    17
#    436   11    58    500.0    0.617    10
#    437    2    37    500.0    0.426     1
#    438    2    50    500.0    0.534     1
#    439    1    19    500.0    0.201     0
# Total extinctions: 0
# Generation time: 1.083 sec (1.097 average)
#
#  ****** Running generation 1670 ******
#
# Population's average fitness: 326.30522 stdev: 187.92797
# Best fitness: 500.00000 - size: (18, 12) - species 434 - id 396354
# Average adjusted fitness: 0.581
# Mean genetic distance 2.742, standard deviation 0.565
# Population of 250 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    434   25    77    500.0    0.803    18
#    436   12    47    500.0    0.583    11
#    437    3    45    500.0    0.612     2
#    438    3    52    500.0    0.617     2
#    439    2    29    500.0    0.293     1
# Total extinctions: 0
# Generation time: 1.115 sec (1.089 average)
#
#  ****** Running generation 1671 ******
#
# Population's average fitness: 350.97200 stdev: 187.93979
# Best fitness: 500.00000 - size: (18, 12) - species 434 - id 396354
# Average adjusted fitness: 0.669
# Mean genetic distance 2.690, standard deviation 0.552
# Population of 251 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    434   26    60    500.0    0.809    19
#    436   13    36    500.0    0.614    12
#    437    4    58    500.0    0.701     3
#    438    4    52    500.0    0.703     3
#    439    3    45    500.0    0.519     2
# Total extinctions: 0
# Generation time: 1.235 sec (1.097 average)
#
#  ****** Running generation 1672 ******
#
# Population's average fitness: 333.52390 stdev: 191.54232
# Best fitness: 500.00000 - size: (18, 12) - species 434 - id 396354
#
# Species 434 with 60 members is stagnated: removing it
# Average adjusted fitness: 0.601
# Mean genetic distance 2.572, standard deviation 0.626
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   14    56    500.0    0.597    13
#    437    5    77    500.0    0.743     4
#    438    5    64    500.0    0.639     4
#    439    4    53    500.0    0.425     3
# Total extinctions: 0
# Generation time: 1.152 sec (1.099 average)
#
#  ****** Running generation 1673 ******
#
# Population's average fitness: 302.36600 stdev: 196.05185
# Best fitness: 500.00000 - size: (13, 10) - species 436 - id 396777
# Average adjusted fitness: 0.590
# Mean genetic distance 2.583, standard deviation 0.590
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   15    58    500.0    0.539    14
#    437    6    71    500.0    0.615     5
#    438    6    68    500.0    0.737     5
#    439    5    53    500.0    0.467     4
# Total extinctions: 0
# Generation time: 1.084 sec (1.104 average)
#
#  ****** Running generation 1674 ******
#
# Population's average fitness: 310.81200 stdev: 195.46157
# Best fitness: 500.00000 - size: (13, 10) - species 436 - id 396777
# Average adjusted fitness: 0.607
# Mean genetic distance 2.593, standard deviation 0.567
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   16    58    500.0    0.602    15
#    437    7    72    500.0    0.697     6
#    438    7    66    500.0    0.629     6
#    439    6    54    500.0    0.502     5
# Total extinctions: 0
# Generation time: 1.062 sec (1.098 average)
#
#  ****** Running generation 1675 ******
# Population's average fitness: 311.41600 stdev: 198.52783
# Best fitness: 500.00000 - size: (13, 10) - species 436 - id 396777
# Average adjusted fitness: 0.609
# Mean genetic distance 2.557, standard deviation 0.573
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   17    54    500.0    0.558    16
#    437    8    71    500.0    0.659     7
#    438    8    69    500.0    0.713     7
#    439    7    56    500.0    0.505     6
# Total extinctions: 0
# Generation time: 1.041 sec (1.103 average)
#
#  ****** Running generation 1676 ******
#
# Population's average fitness: 348.30200 stdev: 187.02402
# Best fitness: 500.00000 - size: (13, 10) - species 436 - id 396777
# Average adjusted fitness: 0.685
# Mean genetic distance 2.575, standard deviation 0.543
# Population of 250 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   18    49    500.0    0.660    17
#    437    9    70    500.0    0.705     8
#    438    9    71    500.0    0.788     8
#    439    8    60    500.0    0.584     7
# Total extinctions: 0
# Generation time: 1.171 sec (1.112 average)
#
#  ****** Running generation 1677 ******
#
# Population's average fitness: 333.45200 stdev: 192.71284
# Best fitness: 500.00000 - size: (13, 10) - species 436 - id 396777
# Average adjusted fitness: 0.648
# Mean genetic distance 2.595, standard deviation 0.544
# Population of 249 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#    436   19    48    500.0    0.549    18
#    437   10    73    500.0    0.692     9
#    438   10    69    500.0    0.805     9
#    439    9    56    500.0    0.548     8
#    440    0     3       --       --     0
# Total extinctions: 0
# Generation time: 1.162 sec (1.126 average)
#
#  ****** Running generation 1678 ******
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-28:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ec9775ede022> in <module>
# ----> 1 run()
#
# <ipython-input-10-fec0200b6da9> in run()
#      14
#      15     pe = neat.ParallelEvaluator(multiprocessing.cpu_count(), eval_genome)
# ---> 16     winner = pop.run(pe.evaluate)
#      17
#      18     # Save the winner.
#
# ~/anaconda3/lib/python3.7/site-packages/neat/population.py in run(self, fitness_function, n)
#      87
#      88             # Evaluate all genomes using the user-provided function.
# ---> 89             fitness_function(list(iteritems(self.population)), self.config)
#      90
#      91             # Gather and report statistics.
#
# ~/anaconda3/lib/python3.7/site-packages/neat/parallel.py in evaluate(self, genomes, config)
#      28         # assign the fitness back to each genome
#      29         for job, (ignored_genome_id, genome) in zip(jobs, genomes):
# ---> 30             genome.fitness = job.get(timeout=self.timeout)
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-8-5db89cd676f6>", line 17, in eval_genome
#     observation, reward, done, info = env.step(action)
#   File "<ipython-input-8-5db89cd676f6>", line 15, in eval_genome
#     vals = net.activate(observation)
#   File "<ipython-input-8-5db89cd676f6>", line 15, in eval_genome
#     vals = net.activate(observation)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "<ipython-input-8-5db89cd676f6>", line 17, in eval_genome
#     observation, reward, done, info = env.step(action)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/wrappers/time_limit.py", line 16, in step
#     observation, reward, done, info = self.env.step(action)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/neat/nn/feed_forward.py", line 16, in activate
#     for k, v in zip(self.input_nodes, inputs):
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/neat/nn/feed_forward.py", line 26, in activate
#     return [self.values[i] for i in self.output_nodes]
#   File "<ipython-input-8-5db89cd676f6>", line 17, in eval_genome
#     observation, reward, done, info = env.step(action)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/wrappers/time_limit.py", line 16, in step
#     observation, reward, done, info = self.env.step(action)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py", line 115, in step
#     xacc = temp - self.polemass_length * thetaacc * costheta / self.total_mass
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py", line 132, in step
#     or x > self.x_threshold
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/wrappers/time_limit.py", line 16, in step
#     observation, reward, done, info = self.env.step(action)
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/classic_control/cartpole.py", line 113, in step
#     temp = (force + self.polemass_length * theta_dot ** 2 * sintheta) / self.total_mass
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-8-5db89cd676f6>", line 16, in eval_genome
#     action = np.argmax(vals)
#   File "<ipython-input-8-5db89cd676f6>", line 8, in eval_genome
#     env = gym.make("CartPole-v1")
#   File "<__array_function__ internals>", line 6, in argmax
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py", line 145, in make
#     return registry.make(id, **kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 1193, in argmax
#     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py", line 90, in make
#     env = spec.make(**kwargs)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 55, in _wrapfunc
#     return _wrapit(obj, method, *args, **kwds)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py", line 63, in make
#     spec = copy.deepcopy(self)
#   File "/home/nitro/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 39, in _wrapit
#     def _wrapit(obj, method, *args, **kwds):
# KeyboardInterrupt
#   File "/home/nitro/anaconda3/lib/python3.7/copy.py", line 180, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/nitro/anaconda3/lib/python3.7/copy.py", line 275, in _reconstruct
#     y = func(*args)
#   File "/home/nitro/anaconda3/lib/python3.7/copyreg.py", line 88, in __newobj__
#     return cls.__new__(cls, *args)
# KeyboardInterrupt

# %%
env = gym.make("BipedalWalker-v3")

observation = env.reset()
# Out:
# /home/nitro/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
observation
# Out:
# array([ 2.74756225e-03, -8.31475118e-07,  6.46787323e-05, -1.59999919e-02,
#         9.21388790e-02, -8.53567690e-05,  8.60166550e-01,  1.46645339e-03,
#         1.00000000e+00,  3.25443558e-02, -8.53464007e-05,  8.53715509e-01,
#         6.03620817e-05,  1.00000000e+00,  4.40813929e-01,  4.45820034e-01,
#         4.61422682e-01,  4.89550084e-01,  5.34102678e-01,  6.02460921e-01,
#         7.09148765e-01,  8.85931671e-01,  1.00000000e+00,  1.00000000e+00])

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
os.path.dirname(os.path.abspath("__file__"))

# %%
# load the winner
with open('winner', 'rb') as f:
    c = pickle.load(f)

print('Loaded genome:')
print(c)

# Load the config file, which is assumed to live in
# the same directory as this script.
local_dir = os.path.dirname(__file__)
config_path = os.path.join(local_dir, 'config')
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     config_path)

net = neat.nn.FeedForwardNetwork.create(c, config)


env = gym.make("BipedalWalker-v3")
observation = env.reset()

done = False
while not done:
    action = net.activate(observation)

    observation, reward, done, info = env.step(action)
    env.render()

# %%
#env = gym.make("BipedalWalker-v2")
env = gym.make("")

observation = env.reset()

print(observation)
print(env.action_space)

done = False
while not done:
    observation, reward, done, info = env.step(env.action_space.sample())
    print(env.action_space.sample())

    env.render()
